# %% [markdown]
# <h1 style="background-color:blue;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 15px 50px;">Table de matière</h1>
#
# * [1. Libraries](#1)
# * [2. Exploration des données](#2)

# %% [markdown]
# <a id='1'></a>
#
# <h1 style="background-color:blue;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 15px 50px;">Librairies</h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import re

# %%
data=pd.read_json('../Data/datasetProjet2022.json')
data
# Out:
#        user_lang tweet_coordinates_geojson  loc_point_geojson  doublon  \
# 0           None                      None                NaN    False
# 1           None                      None                NaN    False
# 2           None                      None                NaN    False
# 3           None                      None                NaN    False
# 4           None                      None                NaN    False
# ...          ...                       ...                ...      ...
# 517296      None                      None                NaN    False
# 517297      None                      None                NaN    False
# 517298      None                      None                NaN    False
# 517299      None                      None                NaN    False
# 517300      None                      None                NaN    False
#
#        country                                       tweet_source  \
# ...

# %%
data[['tweet_text','id_evt','tweet_created_at']]
# Out:
#                                                tweet_text  id_evt  \
# 0       Un #séisme majeur menace #Istanbul – {Sciences...     NaN
# 1       Tremblement de terre M3.1 - FRANCE - 31km de L...     NaN
# 2       Un séisme majeur menace Istanbul – {Sciences²}...     NaN
# 3       Un séisme majeur menace Istanbul – {Sciences²}...     NaN
# 4        je suis morte ça crie comme si y avait un séisme     NaN
# ...                                                   ...     ...
# 517296  Réactions après le tremblement de terre ce jeu...     NaN
# 517297  Lisbonne : églises de Santa María de Carmo jam...     NaN
# 517298  @Ludovic_P_ - Un tremblement de terre.\n- Un v...     NaN
# 517299  Un séisme majeur menace Istanbul – {Sciences²}...     NaN
# 517300  Un séisme majeur menace Istanbul https://t.co/...     NaN
#
#           tweet_created_at
# 0      2019-07-26 12:59:53
# 1      2019-07-26 13:03:46
# 2      2019-07-26 13:06:10
# 3      2019-07-26 13:13:42
# 4      2019-07-26 13:57:45
# ...

# %%
data["id_evt"].unique()
# Out:
# array([ nan, 254., 255., 256., 257., 258., 259., 260., 342., 341., 261.,
#        318., 317., 326., 262., 267., 263., 266., 264., 265., 269., 225.,
#        226., 227., 364., 337., 378., 323., 230., 359., 334., 347., 234.,
#        235., 349., 350., 237., 335., 330., 367., 368., 238., 239., 241.,
#        240., 312., 313., 344., 353., 242., 243., 329., 343., 244., 315.,
#        245., 248., 246., 249., 250., 251., 215., 153., 172., 346., 366.,
#        362., 363., 154., 352., 339., 157., 155., 272., 271., 328., 273.,
#        274., 278., 277., 365., 351., 308., 280., 357., 281., 382., 383.,
#        314., 282., 284., 283., 316., 376., 377., 356., 345., 286., 285.,
#        372., 374., 373., 375., 287., 360., 288., 324., 289., 290., 291.,
#        292., 331., 294., 293., 321., 322., 309., 295., 296., 358., 297.,
#        298., 302., 299., 303., 305., 361., 307., 348., 369., 370., 332.,
#        325., 327., 340., 379., 156., 380., 320., 311., 158., 159., 371.,
# ...
